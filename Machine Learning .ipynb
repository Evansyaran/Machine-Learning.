# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
pip install jupyterthemes
# Out:
# ...
#   Obtaining dependency information for jupyterthemes from https://files.pythonhosted.org/packages/8a/08/9dee6dfd7f2aad6c30282d55c8f495b4dc1e4747b4e2bdbeb80572ddf312/jupyterthemes-0.20.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for lesscpy>=0.11.2 from https://files.pythonhosted.org/packages/2a/da/4a20ba69c9c71ce3d522da5a3c617254d1d1430b71f52b7d46dbf2c06b96/lesscpy-0.15.1-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#     --------------------------------------- 0.1/7.0 MB 2.8 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/7.0 MB 3.5 MB/s eta 0:00:02
#    --- ------------------------------------ 0.6/7.0 MB 3.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/7.0 MB 5.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/7.0 MB 5.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/7.0 MB 5.5 MB/s eta 0:00:02
# ...

# %%
df=pd.read_csv(r"C:\Users\Evans.Ruto\Downloads\homeprices.csv")
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
from jupyterthemes import get_themes
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme

# %%
set_nb_theme('grade3')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #303030;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #303030;
#  background-color: #ffffff;
#  background: #ffffff;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #ffffff;
#  background: #ffffff;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #303030;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #2f2f2f;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
# ...

# %%
# %matplotlib inline
plt.title('price vs area')
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,marker='+',color='red')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')
plt.show()

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# C:\Users\Evans.Ruto\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
#EXERCISE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
can=pd.read_csv(r"C:\Users\Evans.Ruto\Downloads\canada_per_capita_income.csv")
can.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income (US$')
plt.scatter(can.year,can['per capita income (US$)'],marker='*',color='green')

# %%
reg1=linear_model.LinearRegression()
reg1.fit(can[['year']],can['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
reg1.predict([[2020]])
# Out:
# C:\Users\Evans.Ruto\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %% [markdown]
# ### Linear Regression Multiple Variables #HOMEPRICES

# %%
import pandas as pd
import matplotlib.pyplot
import numpy as np
from sklearn import linear_model

# %%
h=pd.read_csv(r"C:\Users\Evans.Ruto\Downloads\homeprices-kitusuru.csv")
h.head()
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
h.bedrooms.median()
# Out:
# 4.0

# %%
h=h.fillna(h.bedrooms.median())
h
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg3=linear_model.LinearRegression()

# %%
reg3.fit(h[['area','bedrooms','age']],h.price)
# Out:
# LinearRegression()

# %%
reg3.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
reg3.intercept_
# Out:
# 221323.00186540408

# %%
reg3.predict([[3000,4,15]])
# Out:
# C:\Users\Evans.Ruto\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([602590.07937407])

# %%
reg3.predict([[2500,4,5]])
# Out:
# C:\Users\Evans.Ruto\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([578876.03748933])

# %% [markdown]
# ### hiring.csv

# %%
# !pip install word2number
import pandas as pd
import numpy as np
from sklearn import linear_model
from word2number import w2n
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5590 sha256=ded8f565a9e188801cf4c36298a73ba7b98bfdc67d7115a4afa002a06b3186b2
#   Stored in directory: c:\users\evans.ruto\appdata\local\pip\cache\wheels\cd\ef\ae\073b491b14d25e2efafcffca9e16b2ee6d114ec5c643ba4f06
# Successfully built word2number
# ...

# %%
hr=pd.read_csv(r"C:\Users\Evans.Ruto\Downloads\hiring.csv")
hr
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
hr.experience=hr.experience.fillna('zero')

# %%
hr
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
hr.experience=hr.experience.apply(w2n.word_to_num)
hr
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000

# %%
round(hr['test_score(out of 10)'].median())
# Out:
# 8

# %%
hr=hr.fillna(round(hr['test_score(out of 10)'].median()))
hr
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    8.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
reg4=linear_model.LinearRegression()

# %%
reg4.fit(hr[['experience','test_score(out of 10)','interview_score(out of 10)',]],hr['salary($)'])
# Out:
# LinearRegression()

# %%
reg4.coef_
# Out:
# array([2812.95487627, 1845.70596798, 2205.24017467])

# %%
reg4.intercept_
# Out:
# 17737.26346433771

# %%
reg4.predict([[2,9,4]])
# Out:
# C:\Users\Evans.Ruto\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([48795.48762737])

# %%
reg4.predict([[12,10,10]])
# Out:
# C:\Users\Evans.Ruto\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([92002.18340611])

# %% [markdown]
# ### Dummy Variables & One- Hot Encoding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
hse=pd.read_csv(r"C:\Users\Evans.Ruto\Downloads\homeprices (5).csv")
hse.head(15)
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
dummies=pd.get_dummies(hse.town)
dummies.astype(int)
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
merged=pd.concat([hse,dummies.astype(int)],axis='columns')
merged
# Out:
#                town  area   price  monroe township  robinsville  west windsor
# 0   monroe township  2600  550000                1            0             0
# 1   monroe township  3000  565000                1            0             0
# 2   monroe township  3200  610000                1            0             0
# 3   monroe township  3600  680000                1            0             0
# 4   monroe township  4000  725000                1            0             0
# 5      west windsor  2600  585000                0            0             1
# 6      west windsor  2800  615000                0            0             1
# 7      west windsor  3300  650000                0            0             1
# 8      west windsor  3600  710000                0            0             1
# 9       robinsville  2600  575000                0            1             0
# 10      robinsville  2900  600000                0            1             0
# ...

# %%
hse1=merged.drop(['town'],axis='columns')
hse1
# Out:
#     area   price  monroe township  robinsville  west windsor
# 0   2600  550000                1            0             0
# 1   3000  565000                1            0             0
# 2   3200  610000                1            0             0
# 3   3600  680000                1            0             0
# 4   4000  725000                1            0             0
# 5   2600  585000                0            0             1
# 6   2800  615000                0            0             1
# 7   3300  650000                0            0             1
# 8   3600  710000                0            0             1
# 9   2600  575000                0            1             0
# 10  2900  600000                0            1             0
# 11  3100  620000                0            1             0
# 12  3600  695000                0            1             0

# %%
X=hse1.drop(['price'],axis='columns')
X
# Out:
#     area  monroe township  robinsville  west windsor
# 0   2600                1            0             0
# 1   3000                1            0             0
# 2   3200                1            0             0
# 3   3600                1            0             0
# 4   4000                1            0             0
# 5   2600                0            0             1
# 6   2800                0            0             1
# 7   3300                0            0             1
# 8   3600                0            0             1
# 9   2600                0            1             0
# 10  2900                0            1             0
# 11  3100                0            1             0
# 12  3600                0            1             0

# %%
y=hse1.price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
from sklearn import linear_model

# %%
model=LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([   126.89744141, -21900.12900452,   3786.28251989,  18113.84648463])

# %%
model.intercept_
# Out:
# 231676.52117832552

# %%
model.predict([[3400,0,1,0]])
# Out:
# C:\Users\Evans.Ruto\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([666914.10449365])

# %%
model.predict([[2800,0,1,0]])
# Out:
# C:\Users\Evans.Ruto\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([590775.6396474])

# %%
model.score(X,y)
# Out:
# 0.9573929037221873

# %% [markdown]
# ### Dummy Excercise

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
carp=pd.read_csv(r"C:\Users\Evans.Ruto\Downloads\carprices.csv")
carp
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
dummy=pd.get_dummies(carp['Car Model'])
dummy.astype(int)
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0         0       1                      0
# 1         0       1                      0
# 2         0       1                      0
# 3         0       1                      0
# 4         0       1                      0
# 5         1       0                      0
# 6         1       0                      0
# 7         1       0                      0
# 8         1       0                      0
# 9         0       0                      1
# 10        0       0                      1
# 11        0       0                      1
# 12        0       0                      1

# %%
carp1=pd.concat([carp,dummy.astype(int)],axis='columns')
carp1
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5  \
# 0                  BMW X5    69000          18000         6        0       1
# 1                  BMW X5    35000          34000         3        0       1
# 2                  BMW X5    57000          26100         5        0       1
# 3                  BMW X5    22500          40000         2        0       1
# 4                  BMW X5    46000          31500         4        0       1
# 5                 Audi A5    59000          29400         5        1       0
# 6                 Audi A5    52000          32000         5        1       0
# 7                 Audi A5    72000          19300         6        1       0
# 8                 Audi A5    91000          12000         8        1       0
# 9   Mercedez Benz C class    67000          22000         6        0       0
# 10  Mercedez Benz C class    83000          20000         7        0       0
# ...

# %%
X=carp1.drop(['Car Model','Sell Price($)'],axis='columns')
X
# Out:
#     Mileage  Age(yrs)  Audi A5  BMW X5  Mercedez Benz C class
# 0     69000         6        0       1                      0
# 1     35000         3        0       1                      0
# 2     57000         5        0       1                      0
# 3     22500         2        0       1                      0
# 4     46000         4        0       1                      0
# 5     59000         5        1       0                      0
# 6     52000         5        1       0                      0
# 7     72000         6        1       0                      0
# 8     91000         8        1       0                      0
# 9     67000         6        0       0                      1
# 10    83000         7        0       0                      1
# 11    79000         7        0       0                      1
# 12    59000         5        0       0                      1

# %%
y=carp1['Sell Price($)']
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
from sklearn import linear_model

# %%
model1=LinearRegression()

# %%
model1.fit(X,y)
# Out:
# LinearRegression()

# %%
model1.coef_
# Out:
# array([-3.70122094e-01, -1.33245363e+03,  6.10375284e+02, -3.67429130e+03,
#         3.06391602e+03])

# %%
model1.intercept_
# Out:
# 55912.70994756205

# %%
model1.score
# Out:
# <bound method RegressorMixin.score of LinearRegression()>

# %% [markdown]
# ### Price of mercedez benz that is 4 yr old with mileage 45000

# %%
model.predict([[45000,4,0,0,1]])
# Out:
# C:\Users\Evans.Ruto\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([36991.31721061])

# %% [markdown]
# ### Price of bmw that is 7yr old with mileage 86000

# %%
model.predict([[86000,7,0,1,0]])
# Out:
# C:\Users\Evans.Ruto\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11080.74313219])

# %% [markdown]
# ### Training_Test_Split

# %%
cp=pd.read_csv(r"C:\Users\Evans.Ruto\Downloads\carprices (1).csv")
cp
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %% [markdown]
# ### Mileage Vs Sell Price

# %%
# %matplotlib inline
plt.title('Mileage Vs Sell Price')
plt.xlabel('Mileage')
plt.ylabel('Sell Price($)')
plt.scatter(cp.Mileage,cp['Sell Price($)'],marker='*',color='green')

# %% [markdown]
# ### Age Vs Sell Price

# %%
# %matplotlib inline
plt.title('Age Vs Sell Price')
plt.xlabel('Age')
plt.ylabel('Sell Price($)')
plt.scatter(cp['Age(yrs)'],cp['Sell Price($)'],marker='+',color='red')

# %%
X=cp[['Mileage','Age(yrs)']]
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y=cp[['Sell Price($)']]
y
# Out:
#     Sell Price($)
# 0           18000
# 1           34000
# 2           26100
# 3           40000
# 4           31500
# 5           26750
# 6           32000
# 7           19300
# 8           12000
# 9           22000
# 10          18700
# 11          19500
# 12          26000
# 13          27500
# 14          19400
# 15          35000
# 16          35500
# 17          19700
# 18          12800
# 19          28200

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %%
len(X_train)
# Out:
# 16

# %%
len(X_test)
# Out:
# 4

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 3     22500         2
# 18    87600         8
# 13    58780         4
# 2     57000         5
# 14    82450         7
# 8     91000         8
# 17    69000         5
# 16    28000         2
# 19    52000         5
# 12    59000         5
# 11    79000         7
# 1     35000         3
# 0     69000         6
# 15    25400         3
# 4     46000         4
# 9     67000         6

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_test
# Out:
#     Sell Price($)
# 7           19300
# 10          18700
# 5           26750
# 6           32000

# %%
clf.score(X_test,y_test)
# Out:
# 0.7332339593090137

# %% [markdown]
# ### Logistic Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
insu=pd.read_csv(r"C:\Users\Evans.Ruto\Downloads\insurance_data.csv")
insu
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
# %matplotlib inline
plt.title('Age Vs bought_insurance')
plt.xlabel('age')
plt.ylabel('bought_insurance')
plt.scatter(insu.age,insu['bought_insurance'],marker='*',color='purple')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(insu[['age']], insu['bought_insurance'], test_size=0.1)

# %%
X_test
# Out:
#     age
# 12   27
# 11   28
# 1    25

# %%
X_train
# Out:
#     age
# 0    22
# 6    55
# 21   26
# 25   54
# 26   23
# 14   49
# 2    47
# 24   50
# 9    61
# 13   29
# 8    62
# 5    56
# 15   55
# 20   21
# 19   18
# 17   58
# 10   18
# 18   19
# 3    52
# 4    46
# 23   45
# 16   25
# 22   40
# 7    60

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()

# %%
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
log.predict(X_test)
# Out:
# array([0, 0, 0], dtype=int64)

# %%
log.score(X_test,y_test)
# Out:
# 1.0

# %%
log.predict_log_proba(X_test)
# Out:
# array([[-0.25201701, -1.50162225],
#        [-0.28055031, -1.40800001],
#        [-0.20252586, -1.69644219]])

# %%
log.predict_proba(X_test)
# Out:
# array([[0.77723152, 0.22276848],
#        [0.75536794, 0.24463206],
#        [0.81666536, 0.18333464]])

# %%
log.predict([[56]])
# Out:
# C:\Users\Evans.Ruto\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
log.predict([[21]])
# Out:
# C:\Users\Evans.Ruto\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
pip install pivottablejs
# Out:
# ...
#
#   Obtaining dependency information for pivottablejs from https://files.pythonhosted.org/packages/0b/0f/46f1c9a1c9bf1540d3b7803753517fa9755cddc648769ba8cd67de82b51c/pivottablejs-0.9.0-py2.py3-none-any.whl.metadata
# ...

# %%
from pivottablejs import pivot_ui

# %%
pivot_ui(carp1)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Linear Regression in Sample DataSet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
comp=pd.read_csv(r"C:\Users\Evans.Ruto\Downloads\1000_Companies (1).csv")
comp.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
sns.heatmap(comp.corr())
# Out:
# <Axes: >

# %%
dummy=pd.get_dummies(comp.State)
dummy.astype(int)
# Out:
#      California  Florida  New York
# 0             0        0         1
# 1             1        0         0
# 2             0        1         0
# 3             0        0         1
# 4             0        1         0
# ..          ...      ...       ...
# 995           1        0         0
# 996           1        0         0
# 997           1        0         0
# 998           1        0         0
# 999           0        0         1
#
# [1000 rows x 3 columns]

# %%
merged=pd.concat([comp,dummy.astype(int)],axis='columns')
merged
# Out:
#      R&D Spend  Administration  Marketing Spend       State        Profit  \
# 0    165349.20      136897.800      471784.1000    New York  192261.83000
# 1    162597.70      151377.590      443898.5300  California  191792.06000
# 2    153441.51      101145.550      407934.5400     Florida  191050.39000
# 3    144372.41      118671.850      383199.6200    New York  182901.99000
# 4    142107.34       91391.770      366168.4200     Florida  166187.94000
# ..         ...             ...              ...         ...           ...
# 995   54135.00      118451.999      173232.6695  California   95279.96251
# 996  134970.00      130390.080      329204.0228  California  164336.60550
# 997  100275.47      241926.310      227142.8200  California  413956.48000
# 998  128456.23      321652.140      281692.3200  California  333962.19000
# 999  161181.72      270939.860      295442.1700    New York  476485.43000
#
#      California  Florida  New York
# 0             0        0         1
# ...

# %%
comp1=merged.drop(['State'],axis='columns')
comp1
# Out:
#      R&D Spend  Administration  Marketing Spend        Profit  California  \
# 0    165349.20      136897.800      471784.1000  192261.83000           0
# 1    162597.70      151377.590      443898.5300  191792.06000           1
# 2    153441.51      101145.550      407934.5400  191050.39000           0
# 3    144372.41      118671.850      383199.6200  182901.99000           0
# 4    142107.34       91391.770      366168.4200  166187.94000           0
# ..         ...             ...              ...           ...         ...
# 995   54135.00      118451.999      173232.6695   95279.96251           1
# 996  134970.00      130390.080      329204.0228  164336.60550           1
# 997  100275.47      241926.310      227142.8200  413956.48000           1
# 998  128456.23      321652.140      281692.3200  333962.19000           1
# 999  161181.72      270939.860      295442.1700  476485.43000           0
#
#      Florida  New York
# 0          0         1
# 1          0         0
# ...

# %%
X=comp1.drop('Profit',axis='columns')
X
# Out:
#      R&D Spend  Administration  Marketing Spend  California  Florida  New York
# 0    165349.20      136897.800      471784.1000           0        0         1
# 1    162597.70      151377.590      443898.5300           1        0         0
# 2    153441.51      101145.550      407934.5400           0        1         0
# 3    144372.41      118671.850      383199.6200           0        0         1
# 4    142107.34       91391.770      366168.4200           0        1         0
# ..         ...             ...              ...         ...      ...       ...
# 995   54135.00      118451.999      173232.6695           1        0         0
# 996  134970.00      130390.080      329204.0228           1        0         0
# 997  100275.47      241926.310      227142.8200           1        0         0
# 998  128456.23      321652.140      281692.3200           1        0         0
# 999  161181.72      270939.860      295442.1700           0        0         1
#
# [1000 rows x 6 columns]

# %%
y=comp1['Profit']
y
# Out:
# 0      192261.83000
# 1      191792.06000
# 2      191050.39000
# 3      182901.99000
# 4      166187.94000
#            ...
# 995     95279.96251
# 996    164336.60550
# 997    413956.48000
# 998    333962.19000
# 999    476485.43000
# Name: Profit, Length: 1000, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
mdl=LinearRegression()

# %%
mdl.fit(X,y)
# Out:
# LinearRegression()

# %%
mdl.predict([[165349.20,136897.800,471784.1000,0,0,1]])
# Out:
# C:\Users\Evans.Ruto\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([200255.34736062])

# %%
mdl.score(X,y)
# Out:
# 0.949893478314043

# %%
mdl.intercept_
# Out:
# -70167.45814579468

# %%
mdl.coef_
# Out:
# array([ 5.53149346e-01,  1.02624663e+00,  8.10861610e-02,  1.16208642e+02,
#        -3.30144893e+02,  2.13936251e+02])

# %% [markdown]
# ### Music Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
music=pd.read_csv(r"\\gdl\shareddata\Users\Evans.Ruto\Desktop\music.csv")
music
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
X=music.drop('genre',axis='columns')
X
# Out:
#     age  gender
# 0    20       1
# 1    23       1
# 2    25       1
# 3    26       1
# 4    29       1
# 5    30       1
# 6    31       1
# 7    33       1
# 8    37       1
# 9    20       0
# 10   21       0
# 11   25       0
# 12   26       0
# 13   27       0
# 14   30       0
# 15   31       0
# 16   34       0
# 17   35       0

# %%
y=music['genre']
y
# Out:
# 0        HipHop
# 1        HipHop
# 2        HipHop
# 3          Jazz
# 4          Jazz
# 5          Jazz
# 6     Classical
# 7     Classical
# 8     Classical
# 9         Dance
# 10        Dance
# 11        Dance
# 12     Acoustic
# 13     Acoustic
# 14     Acoustic
# 15    Classical
# 16    Classical
# 17    Classical
# Name: genre, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
mmodel=DecisionTreeClassifier()

# %%
mmodel.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
mmodel.predict([[21,1],[22,0]])
# Out:
# C:\Users\Evans.Ruto\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop', 'Dance'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.2,random_state=10)

# %%
mmodel.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions=mmodel.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
score=accuracy_score(y_test, predictions)
score
# Out:
# 0.75

# %% [markdown]
# ### Model Persistence

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import joblib

# music = pd.read_csv(r"C:\Users\Evans.Ruto\Downloads\music.csv")

# X = music.drop('genre', axis='columns')
# y = music['genre']

# # Create an instance of DecisionTreeClassifier
# mmodel = DecisionTreeClassifier()

# # Fit the model
# mmodel.fit(X, y)

# # Specify the path for saving the model
# model_path = r"\\gdl\shareddata\Users\Evans.Ruto\Desktop\music-recommender.joblib"

# Save the model using joblib
joblib.dump(mmodel, model_path)
# Out:
# ['\\\\gdl\\shareddata\\Users\\Evans.Ruto\\Desktop\\music-recommender.joblib']

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

music = pd.read_csv(r"C:\Users\Evans.Ruto\Downloads\music.csv")

X = music.drop('genre', axis='columns')
y = music['genre']

# Create an instance of DecisionTreeClassifier
mmodel = DecisionTreeClassifier()

# Fit the model
mmodel.fit(X, y)

tree.export_graphviz(mmodel,out_file='music-recommender.dot',
                     label='all',
                     filled=True,
                     rounded=True,
                     feature_names=['age','gender'],
                     class_names=y.unique())
